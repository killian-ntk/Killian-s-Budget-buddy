# %% [markdown]
# <a href="https://colab.research.google.com/github/killian-ntk/Killian-s-Budget-buddy/blob/main/starter_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏦 Project Overview
#
# Welcome to your **Smart Finance Assistant** development journey! This notebook will evolve from basic CSV processing to a complete AI-powered finance application.
#
# **Final Application Components:**
# - 💬 **AI Chat Interface** - Financial advice personality
# - 📊 **Data Analysis** - CSV transaction processing
# - 🔍 **RAG System** - Retrieval from financial documents
# - 🛠️ **Custom Tools** - Calculators and utilities
# - 🌐 **Gradio UI** - Professional web interface
#
# **Development Approach**: Build progressively from foundation to advanced features, using AI collaboration throughout.

# %% [markdown]
# ---
#
# # 🚀 Getting Started: Foundation Setup
#
# ## Initial Setup
# This cell installs the necessary libraries. In a Colab environment, you would uncomment the first line.

# %%
# Uncomment the line below when running in Google Colab
# !pip install gradio pandas hands-on-ai

# Import core libraries
import pandas as pd
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

print("📦 Core libraries loaded successfully!")
print(f"Pandas version: {pd.__version__}")
# Out:
# 📦 Core libraries loaded successfully!
# Pandas version: 2.2.2

# %% [markdown]
# ## Hands-on-AI Configuration
#
# Set up the hands-on-ai package for advanced features (chat, RAG, tools):

# %%
import os
from hands_on_ai.chat import get_response

# Configure hands-on-ai server connection
os.environ['HANDS_ON_AI_SERVER'] = 'https://ollama.locollm.org'
os.environ['HANDS_ON_AI_MODEL'] = 'gemma3:4b'
os.environ['HANDS_ON_AI_API_KEY'] = 'Curtin2026ISYS20015002'

print("🔑 Hands-on-AI configured successfully!")
# Out:
# 🔑 Hands-on-AI configured successfully!

# %% [markdown]
# The API key this semester is:  **isys2001-assignment-key**

# %% [markdown]
# ## Connection Test
#
# Test that everything is working correctly:

# %%
from hands_on_ai.chat import get_response

# Test the connection to the hands-on-ai server
try:
    response = get_response("Hello! I'm building a Smart Finance Assistant.")
    print("✅ Hands-on-AI connection successful!")
    print(f"Response: {response}")
except Exception as e:
    print(f"❌ Connection issue: {e}")
    print("You can still work on the data processing foundation without this.")
# Out:
# ✅ Hands-on-AI connection successful!
# Response: That's fantastic! A Smart Finance Assistant – that’s a really interesting and potentially incredibly useful project. I’d love to hear more about it.
#
# To help me understand how I can best assist you, could you tell me a bit about your project? Specifically, I’m curious about:
#
# * **What's the main goal of your Assistant?** (e.g., budgeting, tracking expenses, investing advice, bill reminders, etc.)
# * **What platform(s) are you building it for?** (e.g., web app, mobile app, voice assistant integration - Alexa, Google Assistant, etc.)
# * **What's your current stage of development?** (e.g., just starting, have a prototype, building specific features, etc.)
# * **What technologies are you thinking of using?** (e.g., Python, JavaScript, database choices - SQL, NoSQL, etc.)
# * **Are there any specific features you're particularly excited about or struggling with?**
#
#
# ...

# %% [raw]
# ---

# %% [markdown]
# # 🏗️ Foundation: Data Processing Skills
#
# Before building advanced features, establish solid data processing foundations. This section focuses on CSV transaction analysis - the core of your finance assistant.
#
# ## Foundation Skill Checkpoint ✅
#
# **Master these basics before advancing to chat/RAG/tools:**
# - [ ] Load and clean CSV transaction data
# - [ ] Handle real-world data issues (dollar signs, missing values)
# - [ ] Calculate spending summaries by category
# - [ ] Generate business-appropriate insights
# - [ ] Format output for professional presentation
# - [ ] Test functions with various data scenarios
#
# ::: {.callout-tip}
# ## 🤖 AI Collaboration Strategy
#
# For this foundation work, use AI to:
# 1. **Generate initial code** with specific business context
# 2. **Handle data cleaning** and validation
# 3. **Create professional formatting** for outputs
# 4. **Suggest business insights** from data patterns
# 5. **Help with testing** edge cases and error handling
#
# **Remember**: You're directing AI like a junior developer - always review and improve their suggestions!
# :::
#
# ## Sample Transaction Data Setup
#
# Create or load sample transaction data to work with:

# %%
import pandas as pd

# Budget Buddy - Sample transaction data (Australian student expenses)
sample_transactions = {
    'Date': [
        '2024-08-01', '2024-08-03', '2024-08-05', '2024-08-07', '2024-08-10',
        '2024-08-12', '2024-08-15', '2024-08-18', '2024-08-20', '2024-08-22',
        '2024-08-25', '2024-08-28'
    ],
    'Amount': [
        '$85.40', '$12.50', '$220.00', '$6.50', '$45.00',
        '$18.90', '$55.00', '$9.80', '$130.00', '$3.50',
        '$72.30', '-$45.00'
    ],  # Negative = refund
    'Category': [
        'Groceries', 'Transport', 'Rent', 'Coffee', 'Utilities',
        'Dining Out', 'Groceries', 'Transport', 'Entertainment', 'Coffee',
        'Groceries', 'Refund'
    ],
    'Description': [
        'Coles Supermarket', 'Transperth SmartRider', 'Weekly Rent Payment', 'Campus Cafe',
        'Synergy Electricity Bill', 'Hungry Jacks Northbridge', 'Woolworths', 'Transperth SmartRider',
        'Event Cinemas Perth', 'Gloria Jeans', 'IGA Local Store', 'Refund - Returned Textbook'
    ]
}

# Create DataFrame
df_sample = pd.DataFrame(sample_transactions)
print("📋 Budget Buddy - Sample transactions loaded:")
print(df_sample)
# Out:
# 📋 Budget Buddy - Sample transactions loaded:
#           Date   Amount       Category                 Description
# 0   2024-08-01   $85.40      Groceries           Coles Supermarket
# 1   2024-08-03   $12.50      Transport       Transperth SmartRider
# 2   2024-08-05  $220.00           Rent         Weekly Rent Payment
# 3   2024-08-07    $6.50         Coffee                 Campus Cafe
# 4   2024-08-10   $45.00      Utilities    Synergy Electricity Bill
# 5   2024-08-12   $18.90     Dining Out    Hungry Jacks Northbridge
# 6   2024-08-15   $55.00      Groceries                  Woolworths
# 7   2024-08-18    $9.80      Transport       Transperth SmartRider
# 8   2024-08-20  $130.00  Entertainment         Event Cinemas Perth
# 9   2024-08-22    $3.50         Coffee                Gloria Jeans
# 10  2024-08-25   $72.30      Groceries             IGA Local Store
# 11  2024-08-28  -$45.00         Refund  Refund - Returned Textbook

# %% [markdown]
# ---
#
# # 📊 Six-Step Development Methodology
#
# Your notebook must demonstrate the six-step methodology with clear evidence of AI collaboration at each step.
#
# ## STEP 1: Understand the Problem
#
# **🎯 Define Your Finance Problem**
#
# In this section, clearly state your chosen finance problem in business terms.
#
# ::: Budget Buddy helps university students track and understand their monthly spending by analysing CSV transaction exports and providing realistic advice to improve their spending management more efficiently.
# ## Problem Definition Template
#
# *Example: "I want to help people understand their spending habits by analyzing their bank transaction exports. The system should identify spending patterns, highlight potential savings opportunities, and provide actionable financial insights in easy-to-understand language."*
#
# **🤖 AI Prompt to Try:**
# ```
# "Help me brainstorm specific personal finance problems that could be solved
# with a CSV analysis tool. I'm interested in helping people with budgeting
# and spending awareness. What are common financial challenges that data
# analysis could address?"
# ```
#
# **Your Problem Statement:**
# Many university students struggle to track and understand where their money goes each month. I want to help students manage their personal finances by building a Budget Buddy assistant that analyses their bank transaction CSV exports. The system will identify spending patterns across categories like groceries, transport, and dining, highlight areas where they are overspending, and provide clear, actionable advice to help them save money and stay within their budget.
#
# ## STEP 2: Identify Inputs and Outputs
#
# **📥 Define Your Data Flow**
#
# Clearly specify what data you'll work with and what insights you'll generate.
#
# ## Input/Output Analysis Template
#
# **Inputs:**
# - CSV file with transaction data (columns: Date, Amount, Category, Description)
# - User preferences (spending goals, categories to focus on)
# - Time period for analysis
#
# **Outputs:**
# - Total spending summary by category
# - Average spending patterns
# - Spending trend analysis
# - Actionable savings recommendations
# - Visual spending breakdown (future enhancement)
#
# **🤖 AI Prompt to Try:**
# ```
# "For a personal finance assistant that analyzes CSV transaction data,
# what are the most valuable inputs I should collect and outputs I should
# provide? Consider both technical data processing and business value
# for the user."
# ```
#
# **Your Input/Output Definition:**
#
# Inputs:
#
# CSV file with transaction data (Date, Amount, Category, Description)
# User's monthly budget goal amount
# Time period for analysis (e.g. weekly, monthly)
#
# Outputs:
#
# Total spending summary broken down by category
# Percentage of budget used per category
# Identification of top 3 highest spending areas
# Actionable savings recommendations based on spending patterns
#
# ## STEP 3: Work the Problem by Hand
#
# **✋ Manual Calculation Examples**
#
# Show 2-3 worked examples to understand the logic before coding.
#
#
# ## Example Business Calculation
#
# Given this sample data:
#
# | Date | Amount | Category | Description |
# |------|--------|----------|-------------|
# | 2024-08-01 | $45.50 | Groceries | Woolworths |
# | 2024-08-02 | $12.00 | Transport | Opal Card |
# | 2024-08-03 | $89.95 | Entertainment | Concert |
# | 2024-08-04 | -$15.00 | Refund | Returned item |
#
# **Manual Calculations:**
# - Total Spending: $45.50 + $12.00 + $89.95 - $15.00 = $132.45
# - By Category: Groceries $45.50, Transport $12.00, Entertainment $89.95
# - Average Transaction: $132.45 ÷ 4 = $33.11
# - Insight: Entertainment represents 67% of positive spending
#
# **🤖 AI Prompt to Try:**
# ```
# "Give me 3 realistic examples of Australian transaction data with different
# scenarios (normal spending, refunds, large purchases). Show me how to manually
# calculate meaningful financial insights from each scenario."
# ```
#
# **Your Manual Examples:**
# | Date | Amount | Category | Description |
# |------|--------|----------|-------------|
# | 2024-08-01 | $85.40 | Groceries | Coles |
# | 2024-08-02 | $12.50 | Transport | TransPerth |
# | 2024-08-03 | $18.90 | Dine out | HungryJack and KFC |
#
# **Manual Calculations:**
# - Total Spending: $85.40 + $12.50 + $18.90 = $116.80
# - By Category: Groceries $85.40, Transport $12.50, Dining Out $18.90
# - Average Transaction: $116.80 ÷ 3 = $38.93
# - Insight: Groceries represents 73% of spending
#
#
# ## STEP 4: Write Pseudocode
#
# **📝 Plan Your Solution Logic**
#
# Sketch the algorithm in plain English before coding.
#
#
# ## Pseudocode Template
#
# ```
# FUNCTION analyze_spending_data(csv_file):
#     // Step 1: Load and validate data
#     - Read CSV file into DataFrame
#     - Check for required columns (Date, Amount, Category, Description)
#     - Handle missing or invalid data
#
#     // Step 2: Clean financial data
#     - Remove dollar signs from Amount column
#     - Convert to numeric values
#     - Separate positive spending from refunds
#
#     // Step 3: Calculate business metrics
#     - Group transactions by category
#     - Calculate totals, averages, counts per category
#     - Identify spending patterns and outliers
#
#     // Step 4: Generate insights
#     - Calculate percentages of total spending
#     - Identify top spending categories
#     - Suggest potential savings opportunities
#
#     // Step 5: Format for presentation
#     - Create business-friendly output
#     - Include currency formatting
#     - Add explanatory text for insights
#
#     RETURN formatted_analysis
# ```
#
# **🤖 AI Prompt to Try:**
# ```
# "Review my pseudocode for analyzing spending data from a CSV. Are there any
# edge cases I'm missing? What business logic should I add to make this more
# valuable for personal finance insights?"
# ```
#
#
# **Your Pseudocode:**
#
# ```
# FUNCTION analyze_budget_buddy(csv_file):
#     // Step 1: Load and validate data
#     - Read sample_transactions.csv into DataFrame
#     - Check for required columns (Date, Amount, Category, Description)
#     - If columns missing, display clear error message to user
#     - Handle missing or empty rows
#
#     // Step 2: Clean financial data
#     - Remove dollar signs from Amount column
#     - Convert Amount to numeric values
#     - Separate positive spending from refunds (negative values)
#
#     // Step 3: Calculate business metrics
#     - Group transactions by Category
#     - Calculate total spent per category
#     - Calculate average transaction amount
#     - Count number of transactions per category
#     - Identify largest single purchase
#
#     // Step 4: Generate insights
#     - Calculate each category as percentage of total spending
#     - Identify top 3 highest spending categories
#     - Flag categories that exceed 30% of total budget
#     - Suggest savings opportunities based on spending patterns
#
#     // Step 5: Format for presentation
#     - Display results in clear, readable format
#     - Format all amounts as currency (e.g. $85.40)
#     - Add friendly advice message based on top spending category
#
#     RETURN formatted_budget_summary
# ```
#
# ## STEP 5: Convert to Python
#
# **💻 Implementation with AI Collaboration**
#
# Now implement your solution using AI assistance. Focus on creating professional, business-appropriate code.
#
#
# ## 🤖 Implementation Strategy
#
# **Effective AI Prompts for Implementation:**
# ```
# "I'm implementing a Smart Finance Assistant. Based on my pseudocode, please create
# a Python function that [specific functionality]. The code should:
# - Handle real-world CSV data issues (dollar signs, missing values)
# - Include clear comments explaining business logic
# - Use professional variable names
# - Format output for business presentation
# - Include basic error handling"
# ```
#
# **Remember to critique and improve AI responses before using them!**
# :::
#
# ### Foundation Data Processing Functions

# %%
# 🤖 AI Collaboration: Data Loading and Cleaning Function
# Ask AI to help you create a robust data loading function

def load_and_clean_transaction_data(file_path):
    """
    Load and clean transaction data for the Smart Finance Assistant

    🤖 AI Collaboration Prompt:
    "Create a function to load CSV transaction data with Date, Amount, Category,
    Description columns. Handle dollar signs in Amount, missing values, and
    data validation. Include clear business-focused error messages."

    Args:
        file_path: Path to CSV file or file object
    Returns:
        pandas.DataFrame: Cleaned transaction data
    """
    if isinstance(file_path, pd.DataFrame):
        df = file_path.copy()
    else:
        df = pd.read_csv(file_path)

    # Validate required columns
    required_columns = ['Date', 'Amount', 'Category', 'Description']
    missing_columns = [col for col in required_columns if col not in df.columns]
    if missing_columns:
        raise ValueError(f"❌ Missing required columns: {missing_columns}")

    # Clean Amount column - remove dollar signs and convert to numeric
    df['Amount'] = df['Amount'].astype(str).str.replace('$', '', regex=False)
    df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')

    # Handle missing values
    df = df.dropna(subset=['Amount'])
    df['Category'] = df['Category'].fillna('Uncategorised')
    df['Description'] = df['Description'].fillna('No description')

    # Separate spending from refunds
    df['Type'] = df['Amount'].apply(lambda x: 'Refund' if x < 0 else 'Spending')

    print(f"✅ Data loaded successfully! {len(df)} transactions found.")
    return df

# Test your function
clean_data = load_and_clean_transaction_data(df_sample)
print(clean_data)
# Out:
# ✅ Data loaded successfully! 12 transactions found.
#           Date  Amount       Category                 Description      Type
# 0   2024-08-01    85.4      Groceries           Coles Supermarket  Spending
# 1   2024-08-03    12.5      Transport       Transperth SmartRider  Spending
# 2   2024-08-05   220.0           Rent         Weekly Rent Payment  Spending
# 3   2024-08-07     6.5         Coffee                 Campus Cafe  Spending
# 4   2024-08-10    45.0      Utilities    Synergy Electricity Bill  Spending
# 5   2024-08-12    18.9     Dining Out    Hungry Jacks Northbridge  Spending
# 6   2024-08-15    55.0      Groceries                  Woolworths  Spending
# 7   2024-08-18     9.8      Transport       Transperth SmartRider  Spending
# 8   2024-08-20   130.0  Entertainment         Event Cinemas Perth  Spending
# 9   2024-08-22     3.5         Coffee                Gloria Jeans  Spending
# 10  2024-08-25    72.3      Groceries             IGA Local Store  Spending
# ...

# %%
# 🤖 AI Collaboration: Spending Analysis Function
# Ask AI to help you create comprehensive spending analysis

def analyze_spending_patterns(df):
    """
    Analyze spending patterns and generate business insights

    🤖 AI Collaboration Prompt:
    "Create a function that analyzes spending by category, calculates percentages,
    identifies top spending areas, and generates actionable financial insights
    formatted for business presentation."

    Args:
        df: Cleaned transaction DataFrame
    Returns:
        dict: Analysis results and insights
    """
    # Separate spending and refunds for accurate analysis
    spending_df = df[df['Type'] == 'Spending']
    refunds_df = df[df['Type'] == 'Refund']

    # Calculate total spending and refund amounts
    total_spending = spending_df['Amount'].sum()
    total_refunds = abs(refunds_df['Amount'].sum())
    net_spending = total_spending - total_refunds

    # Group transactions by category and calculate business metrics
    category_totals = spending_df.groupby('Category')['Amount'].sum().sort_values(ascending=False)
    category_counts = spending_df.groupby('Category')['Amount'].count()
    category_averages = spending_df.groupby('Category')['Amount'].mean()

    # Calculate percentage of total spending per category
    category_percentages = (category_totals / total_spending * 100).round(2)

    # Identify top 3 highest spending categories
    top_3_categories = category_totals.head(3)

    # Identify largest single purchase
    largest_purchase_idx = spending_df['Amount'].idxmax()
    largest_purchase = spending_df.loc[largest_purchase_idx]

    # Flag categories exceeding 30% of total budget
    high_spend_categories = category_percentages[category_percentages > 30].index.tolist()

    # Print business-friendly summary
    print("=" * 50)
    print("📊 BUDGET BUDDY - SPENDING ANALYSIS REPORT")
    print("=" * 50)
    print(f"\n💰 Total Spending:   ${total_spending:.2f}")
    print(f"↩️  Total Refunds:    ${total_refunds:.2f}")
    print(f"📉 Net Spending:     ${net_spending:.2f}")
    print(f"\n📂 Spending by Category:")
    for category in category_totals.index:
        print(f"   {category:<20} ${category_totals[category]:.2f}  ({category_percentages[category]:.1f}%)")
    print(f"\n🏆 Top 3 Spending Categories:")
    for i, category in enumerate(top_3_categories.index, 1):
        print(f"   {i}. {category}: ${top_3_categories[category]:.2f}")
    print(f"\n🔺 Largest Single Purchase: {largest_purchase['Description']} (${largest_purchase['Amount']:.2f})")
    if high_spend_categories:
        print(f"\n⚠️  High Spend Alert: {', '.join(high_spend_categories)} exceeds 30% of total budget")

    # Return results as dictionary for use in other functions
    return {
        'total_spending': total_spending,
        'total_refunds': total_refunds,
        'net_spending': net_spending,
        'category_totals': category_totals,
        'category_percentages': category_percentages,
        'category_averages': category_averages,
        'category_counts': category_counts,
        'top_3_categories': top_3_categories,
        'largest_purchase': largest_purchase,
        'high_spend_categories': high_spend_categories
    }

# Test your function
analysis = analyze_spending_patterns(clean_data)
# Out:
# ...
# 📊 BUDGET BUDDY - SPENDING ANALYSIS REPORT
# ...
#
# 💰 Total Spending:   $658.90
# ↩️  Total Refunds:    $45.00
# 📉 Net Spending:     $613.90
#
# 📂 Spending by Category:
#    Rent                 $220.00  (33.4%)
#    Groceries            $212.70  (32.3%)
#    Entertainment        $130.00  (19.7%)
#    Utilities            $45.00  (6.8%)
#    Transport            $22.30  (3.4%)
#    Dining Out           $18.90  (2.9%)
#    Coffee               $10.00  (1.5%)
#
# 🏆 Top 3 Spending Categories:
#    1. Rent: $220.00
#    2. Groceries: $212.70
#    3. Entertainment: $130.00
#
# 🔺 Largest Single Purchase: Weekly Rent Payment ($220.00)
#
# ⚠️  High Spend Alert: Rent, Groceries exceeds 30% of total budget

# %%
# 🤖 AI Collaboration: Business Insights Generator
# Ask AI to help create professional financial recommendations

def generate_financial_recommendations(analysis_data):
    """
    Generate actionable financial recommendations based on spending analysis

    🤖 AI Collaboration Prompt:
    "Based on spending analysis data, create professional financial
    recommendations. Include specific savings opportunities, spending
    pattern observations, and actionable advice formatted for a
    personal finance app user."

    Args:
        analysis_data: Dictionary with spending analysis results
    Returns:
        str: Formatted recommendations report
    """
    recommendations = []

    # Extract data from analysis dictionary
    total_spending = analysis_data['total_spending']
    total_refunds = analysis_data['total_refunds']
    net_spending = analysis_data['net_spending']
    category_totals = analysis_data['category_totals']
    category_percentages = analysis_data['category_percentages']
    top_3_categories = analysis_data['top_3_categories']
    high_spend_categories = analysis_data['high_spend_categories']
    largest_purchase = analysis_data['largest_purchase']

    # Build recommendations report header
    report = []
    report.append("=" * 50)
    report.append("💡 BUDGET BUDDY - FINANCIAL RECOMMENDATIONS")
    report.append("=" * 50)

    # Observation 1: Overall spending summary
    report.append(f"\n📋 SPENDING SUMMARY")
    report.append(f"   Your total spending this period was ${total_spending:.2f}.")
    if total_refunds > 0:
        report.append(f"   After ${total_refunds:.2f} in refunds, your net spending is ${net_spending:.2f}.")

    # Observation 2: Top spending category advice
    top_category = top_3_categories.index[0]
    top_amount = top_3_categories.iloc[0]
    top_percentage = category_percentages[top_category]
    report.append(f"\n🔍 TOP SPENDING INSIGHT")
    report.append(f"   Your biggest expense is {top_category} at ${top_amount:.2f} ({top_percentage:.1f}% of total).")

    # Generate specific advice based on top category
    category_advice = {
        'Dining Out': "Consider meal prepping at home a few days a week to reduce dining costs.",
        'Entertainment': "Look for free or discounted events in your area to cut entertainment costs.",
        'Coffee': "Making coffee at home could save you over $100 per month.",
        'Groceries': "Try shopping at discount supermarkets or buying in bulk to reduce grocery bills.",
        'Transport': "Consider a weekly or monthly transport pass for better value.",
        'Utilities': "Review your utility plans — switching providers could reduce your bills.",
        'Rent': "Your rent is your biggest fixed cost. Consider splitting costs with housemates if possible."
    }
    if top_category in category_advice:
        report.append(f"   💡 Tip: {category_advice[top_category]}")
    else:
        report.append(f"   💡 Tip: Review your {top_category} spending to find potential savings.")

    # Observation 3: High spend category warnings
    if high_spend_categories:
        report.append(f"\n⚠️  HIGH SPEND WARNINGS")
        for category in high_spend_categories:
            report.append(f"   {category} accounts for {category_percentages[category]:.1f}% of your budget — consider setting a spending limit.")

    # Observation 4: Largest purchase note
    report.append(f"\n🔺 LARGEST PURCHASE")
    report.append(f"   Your biggest single transaction was {largest_purchase['Description']} at ${largest_purchase['Amount']:.2f}.")
    if largest_purchase['Amount'] > total_spending * 0.25:
        report.append(f"   This single purchase made up more than 25% of your total spending.")

    # Observation 5: Savings opportunities
    report.append(f"\n✅ SAVINGS OPPORTUNITIES")
    wants_categories = ['Dining Out', 'Entertainment', 'Coffee']
    wants_total = sum(category_totals.get(cat, 0) for cat in wants_categories if cat in category_totals)
    if wants_total > 0:
        report.append(f"   You spent ${wants_total:.2f} on non-essential items (Dining Out, Entertainment, Coffee).")
        report.append(f"   Reducing these by 20% could save you ${wants_total * 0.2:.2f} this period.")

    report.append(f"\n{'=' * 50}")
    report.append("Keep tracking your spending with Budget Buddy! 💰")
    report.append("=" * 50)

    # Join and print the report
    final_report = "\n".join(report)
    print(final_report)
    return final_report

# Test your function
recommendations = generate_financial_recommendations(analysis)
print(recommendations)
# Out:
# ...
# 💡 BUDGET BUDDY - FINANCIAL RECOMMENDATIONS
# ...
#
# 📋 SPENDING SUMMARY
#    Your total spending this period was $658.90.
#    After $45.00 in refunds, your net spending is $613.90.
#
# 🔍 TOP SPENDING INSIGHT
#    Your biggest expense is Rent at $220.00 (33.4% of total).
#    💡 Tip: Your rent is your biggest fixed cost. Consider splitting costs with housemates if possible.
#
# ⚠️  HIGH SPEND WARNINGS
#    Rent accounts for 33.4% of your budget — consider setting a spending limit.
#    Groceries accounts for 32.3% of your budget — consider setting a spending limit.
#
# 🔺 LARGEST PURCHASE
#    Your biggest single transaction was Weekly Rent Payment at $220.00.
#    This single purchase made up more than 25% of your total spending.
#
# ✅ SAVINGS OPPORTUNITIES
#    You spent $158.90 on non-essential items (Dining Out, Entertainment, Coffee).
#    Reducing these by 20% could save you $31.78 this period.
#
# ...
# Keep tracking your spending with Budget Buddy! 💰
# ...

# %% [markdown]
# ---
#
# # 🌐 Advanced Features: Integrating AI Components
#
# Once your foundation data processing is solid, integrate advanced AI features using hands-on-ai.
#
# ## Chat Interface Integration

# %%
# 🤖 AI Collaboration: Financial Advice Chatbot
# Ask AI to help you create a finance-focused chat personality

from hands_on_ai.chat import get_response

def create_finance_chat_personality(user_message):
    """
    Set up a financial advisor chat personality using hands-on-ai

    🤖 AI Collaboration Prompt:
    "Help me create a system prompt for a friendly, professional financial
    advisor chatbot that can provide spending advice based on transaction
    analysis. The personality should be encouraging but practical."

    Args:
        user_message: The user's finance question
    Returns:
        str: AI financial advisor response
    """
    system_prompt = """You are Budget Buddy, a friendly and practical personal
    finance advisor helping Australian university students manage their money.
    You provide clear, actionable advice on budgeting, spending habits, and
    savings goals. Keep responses concise, encouraging, and easy to understand.
    Always suggest realistic steps the user can take immediately."""

    response = get_response(
        user_message,
        system=system_prompt,
        personality="friendly"
    )
    return response

# Test your chatbot
response = create_finance_chat_personality("I spend too much on coffee, what should I do?")
print(response)
# Out:
# Hey there! It’s super common to love a coffee – but it *can* add up fast. Let’s tackle this.
#
# **Here’s what you can do *right now*:**
#
# 1. **Track it:** For one week, write down *every* coffee you buy. This will show exactly how much you're spending.
# 2. **Swap it:**  Try making your own coffee – it's way cheaper! Even just a few times a week can make a difference.
# 3. **Small Change:** If you *do* buy coffee, opt for a smaller size or a cheaper alternative.
#
# Want me to help you set a realistic coffee budget? 😊

# %% [markdown]
# ## RAG System for Financial Documents

# %%
# 🤖 AI Collaboration: Document Retrieval Setup
# Ask AI to help you set up RAG for financial documents

from hands_on_ai.chat import get_response

def setup_financial_rag(user_question):
    """
    Set up RAG system for financial documents and transaction data

    🤖 AI Collaboration Prompt:
    "Help me set up a RAG system that can retrieve information from
    financial documents, budgeting guides, and transaction summaries
    to answer user questions about personal finance."

    Args:
        user_question: Question about the user's finances
    Returns:
        str: AI response based on transaction data
    """
    # Use df_sample already defined in the foundation section as knowledge base
    context = df_sample.to_string()

    # Build prompt with transaction data as context (RAG approach)
    prompt = f"""Here is the user's transaction data:

{context}

Based on this data, please answer the following question:
{user_question}"""

    # Retrieve and respond based on financial document context
    response = get_response(
        prompt,
        system="You are Budget Buddy, a personal finance assistant. Analyse the provided transaction data and give clear, practical financial advice."
    )
    return response

# Test your RAG system
answer = setup_financial_rag("What's a good budgeting strategy for someone who overspends on entertainment?")
print(answer)
# Out:
# Okay, let's analyze your spending and create a budgeting strategy to tackle that entertainment overspending!
#
# **Analysis of Your Spending:**
#
# Looking at your transactions, it’s clear you've been spending a significant amount on entertainment. Specifically:
#
# * **Entertainment:** $130.00 (Event Cinemas) - This is your highest single expense.
# * **Groceries:** Roughly $200 over the period -  A reasonable amount, but worth keeping an eye on.
# * **Transport:** $28.80 -  Okay, within expectations.
# * **Coffee:** $29.30 – Manageable.
# * **Dining Out:** $18.90 – A small, occasional expense.
#
# **The Problem: Entertainment Overspending**
#
# Your biggest issue is consistently spending over $130 on entertainment. This is significantly higher than other categories and is a very common area for people to overspend.
#
# **Budgeting Strategy for Entertainment:**
#
# Here’s a practical strategy, broken down into steps:
#
# **1. Set a Realistic Entertainment Budget:**
#
# ...

# %% [markdown]
# ## Custom Financial Tools

# %%
# 🤖 AI Collaboration: Custom Tool Development
# Ask AI to help you create useful financial calculators

from hands_on_ai.chat import get_response

def create_savings_calculator_tool(current_savings, monthly_contribution, target_amount):
    """
    Create a custom savings goal calculator as an agent tool

    🤖 AI Collaboration Prompt:
    "Create a savings goal calculator function that takes current savings,
    monthly contribution, and target amount, then calculates time to reach
    goal. Format output for user-friendly display."

    Args:
        current_savings: Current amount saved ($)
        monthly_contribution: Monthly savings contribution ($)
        target_amount: Savings goal target ($)
    Returns:
        str: Formatted savings goal report
    """
    # Validate inputs
    if monthly_contribution <= 0:
        return "❌ Monthly contribution must be greater than zero."
    if current_savings >= target_amount:
        return "✅ You have already reached your savings goal!"

    # Calculate months needed to reach target
    remaining = target_amount - current_savings
    months_needed = remaining / monthly_contribution
    years = int(months_needed // 12)
    months = int(months_needed % 12)

    # Format results for user-friendly display
    print("=" * 50)
    print("💰 BUDGET BUDDY - SAVINGS GOAL CALCULATOR")
    print("=" * 50)
    print(f"\n   Current Savings:       ${current_savings:.2f}")
    print(f"   Monthly Contribution:  ${monthly_contribution:.2f}")
    print(f"   Savings Target:        ${target_amount:.2f}")
    print(f"   Remaining Amount:      ${remaining:.2f}")
    print(f"\n🎯 Time to reach goal: {years} years and {months} months")

    if months_needed <= 6:
        print("⭐ Great progress! You're almost there.")
    elif months_needed <= 12:
        print("💪 Keep it up! You'll reach your goal within a year.")
    else:
        print(f"💡 Tip: Increasing your monthly contribution by $50 would save you {50*months_needed/monthly_contribution:.0f} months.")

    print("=" * 50)

    result = f"Time to reach ${target_amount:.2f} goal: {years} years and {months} months."
    return result

# Test your savings calculator
result = create_savings_calculator_tool(
    current_savings=500,
    monthly_contribution=200,
    target_amount=5000
)
print(result)
# Out:
# ...
# 💰 BUDGET BUDDY - SAVINGS GOAL CALCULATOR
# ...
#
#    Current Savings:       $500.00
#    Monthly Contribution:  $200.00
#    Savings Target:        $5000.00
#    Remaining Amount:      $4500.00
#
# 🎯 Time to reach goal: 1 years and 10 months
# 💡 Tip: Increasing your monthly contribution by $50 would save you 6 months.
# ...
# Time to reach $5000.00 goal: 1 years and 10 months.

# %% [markdown]
# ## Gradio UI Integration

# %%
# 🤖 AI Collaboration: Professional UI Design
# Ask AI to help you create a comprehensive Gradio interface

import gradio as gr

def create_finance_assistant_ui():
    """
    Create a comprehensive Gradio interface for the Smart Finance Assistant

    🤖 AI Collaboration Prompt:
    "Help me design a Gradio interface that combines CSV upload, spending
    analysis, chat functionality, and custom tools in a user-friendly
    layout suitable for a personal finance application."
    """

    # Tab 1: Spending Analysis function
    def analyze_csv(file):
        try:
            df = pd.read_csv(file.name)
            df['Amount'] = df['Amount'].astype(str).str.replace('$', '', regex=False)
            df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')
            df = df.dropna(subset=['Amount'])
            df['Type'] = df['Amount'].apply(lambda x: 'Refund' if x < 0 else 'Spending')

            spending_df = df[df['Type'] == 'Spending']
            total_spending = spending_df['Amount'].sum()
            category_totals = spending_df.groupby('Category')['Amount'].sum().sort_values(ascending=False)
            category_percentages = (category_totals / total_spending * 100).round(2)

            report = f"💰 Total Spending: ${total_spending:.2f}\n\n📂 Spending by Category:\n"
            for cat in category_totals.index:
                report += f"   {cat:<20} ${category_totals[cat]:.2f} ({category_percentages[cat]:.1f}%)\n"
            return report
        except Exception as e:
            return f"❌ Error analysing file: {e}"

    # Tab 2: Chat function
    def chat_with_buddy(user_message):
        try:
            response = get_response(
                user_message,
                system="You are Budget Buddy, a friendly personal finance assistant for Australian university students. Give clear, practical, and encouraging financial advice.",
                personality="friendly"
            )
            return response
        except Exception as e:
            return f"❌ Chat error: {e}"

    # Tab 3: Savings Calculator function
    def savings_calculator(current_savings, monthly_contribution, target_amount):
        try:
            if monthly_contribution <= 0:
                return "❌ Monthly contribution must be greater than zero."
            if current_savings >= target_amount:
                return "✅ You have already reached your savings goal!"

            remaining = target_amount - current_savings
            months_needed = remaining / monthly_contribution
            years = int(months_needed // 12)
            months = int(months_needed % 12)

            result = f"💰 SAVINGS GOAL CALCULATOR\n"
            result += f"{'=' * 40}\n"
            result += f"Current Savings:      ${current_savings:.2f}\n"
            result += f"Monthly Contribution: ${monthly_contribution:.2f}\n"
            result += f"Target Amount:        ${target_amount:.2f}\n"
            result += f"Remaining:            ${remaining:.2f}\n"
            result += f"{'=' * 40}\n"
            result += f"🎯 Time to reach goal: {years} years and {months} months"
            return result
        except Exception as e:
            return f"❌ Calculator error: {e}"

    # Build Gradio UI with tabs
    with gr.Blocks(title="Budget Buddy 💰") as demo:
        gr.Markdown("# 💰 Budget Buddy - Smart Finance Assistant")
        gr.Markdown("Your personal finance assistant for smarter spending decisions.")

        with gr.Tabs():
            # Tab 1: Spending Analysis
            with gr.Tab("📊 Spending Analysis"):
                gr.Markdown("### Upload your transaction CSV to analyse your spending")
                csv_input = gr.File(label="Upload CSV File", file_types=[".csv"])
                analyze_btn = gr.Button("Analyse Spending", variant="primary")
                analysis_output = gr.Textbox(label="Spending Analysis Report", lines=15)
                analyze_btn.click(fn=analyze_csv, inputs=csv_input, outputs=analysis_output)

            # Tab 2: Chat with Budget Buddy
            with gr.Tab("💬 Chat with Budget Buddy"):
                gr.Markdown("### Ask Budget Buddy for financial advice")
                chat_input = gr.Textbox(label="Your Question", placeholder="e.g. How can I reduce my grocery spending?")
                chat_btn = gr.Button("Ask Budget Buddy", variant="primary")
                chat_output = gr.Textbox(label="Budget Buddy's Response", lines=10)
                chat_btn.click(fn=chat_with_buddy, inputs=chat_input, outputs=chat_output)

            # Tab 3: Savings Calculator
            with gr.Tab("🎯 Savings Calculator"):
                gr.Markdown("### Calculate how long it will take to reach your savings goal")
                current_savings_input = gr.Number(label="Current Savings ($)", value=500)
                monthly_input = gr.Number(label="Monthly Contribution ($)", value=200)
                target_input = gr.Number(label="Savings Target ($)", value=5000)
                calc_btn = gr.Button("Calculate", variant="primary")
                calc_output = gr.Textbox(label="Results", lines=10)
                calc_btn.click(fn=savings_calculator, inputs=[current_savings_input, monthly_input, target_input], outputs=calc_output)

    return demo

# Launch your complete application
demo = create_finance_assistant_ui()
demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://58ea32db3e79fc1606.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://58ea32db3e79fc1606.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ---
#
# # 🧪 STEP 6: Test with a Variety of Data
#
# **🔍 Comprehensive Testing Strategy**
#
# Create thorough tests for your Smart Finance Assistant to ensure it handles real-world scenarios.
#
# ::: {.callout-tip}
# ## 🤖 AI Collaboration for Testing
#
# **Effective Testing Prompts:**
# ```
# "Help me create comprehensive test cases for my finance assistant. Include:
# - Normal transaction data
# - Edge cases (refunds, large amounts, missing data)
# - Invalid data scenarios (corrupted files, wrong formats)
# - Business logic validation (spending calculations, recommendations)
# Create assert statements to verify each scenario."
# ```
# :::
#
# ## Foundation Function Tests

# %%
# 🤖 AI Collaboration: Comprehensive Test Suite
# Ask AI to help you create thorough test cases

def create_test_datasets():
    """
    Create various test datasets for comprehensive testing

    🤖 AI Collaboration Prompt:
    "Create realistic test datasets for a finance assistant including:
    1. Normal spending data with various categories
    2. Edge cases: refunds (negative amounts), missing data, zero amounts
    3. Data quality issues: invalid formats, extreme values
    4. Business scenarios: high spending months, savings patterns
    Include Australian business names and realistic amounts."
    """
    # Dataset 1: Normal spending data
    normal_data = pd.DataFrame({
        'Date': ['2024-08-01', '2024-08-02', '2024-08-03', '2024-08-04'],
        'Amount': ['$85.40', '$12.50', '$45.00', '$18.90'],
        'Category': ['Groceries', 'Transport', 'Utilities', 'Dining Out'],
        'Description': ['Coles', 'Transperth', 'Synergy', 'Hungry Jacks']
    })

    # Dataset 2: Edge cases with refunds and missing data
    edge_case_data = pd.DataFrame({
        'Date': ['2024-08-01', '2024-08-02', '2024-08-03', '2024-08-04'],
        'Amount': ['$130.00', '-$45.00', '$0.00', '$9.80'],
        'Category': ['Entertainment', 'Refund', 'Groceries', 'Transport'],
        'Description': ['Event Cinemas', 'Returned Item', 'Free Sample', 'Transperth']
    })

    # Dataset 3: Invalid data formats
    invalid_data = pd.DataFrame({
        'Date': ['2024-08-01', '2024-08-02', '2024-08-03'],
        'Amount': ['$55.00', 'invalid', None],
        'Category': ['Groceries', None, 'Transport'],
        'Description': ['Woolworths', 'Unknown', None]
    })

    return normal_data, edge_case_data, invalid_data


def test_data_loading_function():
    """
    Test the data loading and cleaning functionality

    🤖 AI Collaboration Prompt:
    "Create assert statements to test my data loading function with:
    - Valid CSV data
    - CSV with dollar signs in amounts
    - Missing values and invalid data
    - Empty files and corrupted data
    Verify that cleaning works correctly and errors are handled gracefully."
    """
    print("🧪 Testing data loading function...")

    normal_data, edge_case_data, invalid_data = create_test_datasets()

    # Test 1: Normal data loads correctly
    result = load_and_clean_transaction_data(normal_data)
    assert result is not None, "Normal data should load successfully"
    assert len(result) == 4, "Should have 4 transactions"
    print("   ✅ Test 1 passed: Normal data loads correctly")

    # Test 2: Dollar signs are removed and amounts are numeric
    assert result['Amount'].dtype in ['float64', 'int64'], "Amount should be numeric after cleaning"
    assert result['Amount'].iloc[0] == 85.40, "First amount should be 85.40 after removing $"
    print("   ✅ Test 2 passed: Dollar signs removed correctly")

    # Test 3: Refunds are correctly identified
    edge_result = load_and_clean_transaction_data(edge_case_data)
    assert 'Type' in edge_result.columns, "Type column should exist"
    assert edge_result[edge_result['Amount'] < 0]['Type'].iloc[0] == 'Refund', "Negative amounts should be Refund"
    print("   ✅ Test 3 passed: Refunds identified correctly")

    # Test 4: Invalid amounts are handled gracefully
    invalid_result = load_and_clean_transaction_data(invalid_data)
    assert invalid_result is not None, "Function should handle invalid data without crashing"
    assert invalid_result['Amount'].isna().sum() == 0, "Invalid amounts should be removed"
    print("   ✅ Test 4 passed: Invalid data handled gracefully")


def test_spending_analysis():
    """
    Test spending analysis calculations

    🤖 AI Collaboration Prompt:
    "Create tests for spending analysis that verify:
    - Category totals are calculated correctly
    - Percentages add up to 100%
    - Refunds are handled appropriately
    - Edge cases like single transactions or empty categories
    Use assert statements with known expected results."
    """
    print("🧪 Testing spending analysis...")

    normal_data, _, _ = create_test_datasets()
    clean = load_and_clean_transaction_data(normal_data)
    analysis = analyze_spending_patterns(clean)

    # Test 1: Total spending is calculated correctly
    expected_total = 85.40 + 12.50 + 45.00 + 18.90
    assert round(analysis['total_spending'], 2) == round(expected_total, 2), "Total spending should match expected"
    print("   ✅ Test 1 passed: Total spending calculated correctly")

    # Test 2: Category percentages add up to 100%
    total_percentage = analysis['category_percentages'].sum()
    assert round(total_percentage, 0) == 100, "Category percentages should add up to 100%"
    print("   ✅ Test 2 passed: Percentages add up to 100%")

    # Test 3: Top 3 categories are returned
    assert len(analysis['top_3_categories']) <= 3, "Should return at most 3 top categories"
    print("   ✅ Test 3 passed: Top 3 categories identified correctly")

    # Test 4: Refunds are separated from spending
    assert analysis['total_refunds'] == 0, "Normal data should have no refunds"
    print("   ✅ Test 4 passed: Refunds separated correctly")


def test_business_insights():
    """
    Test business recommendation generation

    🤖 AI Collaboration Prompt:
    "Create tests that verify business insights are appropriate:
    - High spending categories are identified correctly
    - Savings opportunities are realistic
    - Recommendations match spending patterns
    - Output format is user-friendly"
    """
    print("🧪 Testing business insights...")

    normal_data, _, _ = create_test_datasets()
    clean = load_and_clean_transaction_data(normal_data)
    analysis = analyze_spending_patterns(clean)
    recommendations = generate_financial_recommendations(analysis)

    # Test 1: Recommendations are returned as a string
    assert isinstance(recommendations, str), "Recommendations should be a string"
    print("   ✅ Test 1 passed: Recommendations returned as string")

    # Test 2: Recommendations are not empty
    assert len(recommendations) > 0, "Recommendations should not be empty"
    print("   ✅ Test 2 passed: Recommendations are not empty")

    # Test 3: Recommendations mention top spending category
    top_category = analysis['top_3_categories'].index[0]
    assert top_category in recommendations, "Recommendations should mention top spending category"
    print("   ✅ Test 3 passed: Top spending category mentioned in recommendations")

    # Test 4: High spend categories flagged correctly
    assert isinstance(analysis['high_spend_categories'], list), "High spend categories should be a list"
    print("   ✅ Test 4 passed: High spend categories correctly identified")


# Run all tests
print("🔍 COMPREHENSIVE TESTING SUITE")
print("=" * 40)

try:
    create_test_datasets()
    test_data_loading_function()
    test_spending_analysis()
    test_business_insights()
    print("\n✅ All tests passed! Your finance assistant is working correctly.")
except AssertionError as e:
    print(f"❌ Test failed: {e}")
except Exception as e:
    print(f"⚠️ Test error: {e}")
# Out:
# 🔍 COMPREHENSIVE TESTING SUITE
# ...
# 🧪 Testing data loading function...
# ✅ Data loaded successfully! 4 transactions found.
#    ✅ Test 1 passed: Normal data loads correctly
#    ✅ Test 2 passed: Dollar signs removed correctly
# ✅ Data loaded successfully! 4 transactions found.
#    ✅ Test 3 passed: Refunds identified correctly
# ✅ Data loaded successfully! 1 transactions found.
#    ✅ Test 4 passed: Invalid data handled gracefully
# 🧪 Testing spending analysis...
# ✅ Data loaded successfully! 4 transactions found.
# ...
# 📊 BUDGET BUDDY - SPENDING ANALYSIS REPORT
# ...
#
# 💰 Total Spending:   $161.80
# ↩️  Total Refunds:    $0.00
# 📉 Net Spending:     $161.80
#
# 📂 Spending by Category:
#    Groceries            $85.40  (52.8%)
#    Utilities            $45.00  (27.8%)
#    Dining Out           $18.90  (11.7%)
#    Transport            $12.50  (7.7%)
#
# 🏆 Top 3 Spending Categories:
#    1. Groceries: $85.40
#    2. Utilities: $45.00
#    3. Dining Out: $18.90
#
# ...

# %% [markdown]
# ## Advanced Integration Tests

# %%
# 🤖 AI Collaboration: Integration Testing
# Ask AI to help test the complete system integration

def test_full_workflow():
    """
    Test the complete workflow from CSV upload to final recommendations

    🤖 AI Collaboration Prompt:
    "Create an end-to-end test that:
    1. Loads sample CSV data
    2. Runs complete analysis pipeline
    3. Generates chat responses about the data
    4. Verifies RAG system retrieval
    5. Tests custom tool functionality
    Ensure all components work together seamlessly."
    """
    print("🧪 Testing complete workflow integration...")

    # Step 1: Load and clean data
    clean = load_and_clean_transaction_data(df_sample)
    assert clean is not None, "Data loading should succeed"
    assert len(clean) > 0, "Cleaned data should not be empty"
    assert 'Type' in clean.columns, "Type column should exist after cleaning"
    print("   ✅ Step 1 passed: Data loading and cleaning works")

    # Step 2: Run spending analysis
    analysis = analyze_spending_patterns(clean)
    assert analysis is not None, "Analysis should return results"
    assert 'total_spending' in analysis, "Analysis should include total spending"
    assert analysis['total_spending'] > 0, "Total spending should be greater than zero"
    print("   ✅ Step 2 passed: Spending analysis pipeline works")

    # Step 3: Generate recommendations
    recommendations = generate_financial_recommendations(analysis)
    assert recommendations is not None, "Recommendations should be generated"
    assert isinstance(recommendations, str), "Recommendations should be a string"
    assert len(recommendations) > 0, "Recommendations should not be empty"
    print("   ✅ Step 3 passed: Recommendations generated successfully")

    # Step 4: Test chat functionality
    chat_response = create_finance_chat_personality("How can I save more money each month?")
    assert chat_response is not None, "Chat should return a response"
    assert isinstance(chat_response, str), "Chat response should be a string"
    assert len(chat_response) > 0, "Chat response should not be empty"
    print("   ✅ Step 4 passed: Chat functionality works")

    # Step 5: Test RAG system
    rag_response = setup_financial_rag("What is my highest spending category?")
    assert rag_response is not None, "RAG should return a response"
    assert isinstance(rag_response, str), "RAG response should be a string"
    print("   ✅ Step 5 passed: RAG system works")

    # Step 6: Test savings calculator tool
    calc_result = create_savings_calculator_tool(500, 200, 5000)
    assert calc_result is not None, "Calculator should return a result"
    assert isinstance(calc_result, str), "Calculator result should be a string"
    print("   ✅ Step 6 passed: Savings calculator tool works")


def test_error_handling():
    """
    Test error handling and user experience

    🤖 AI Collaboration Prompt:
    "Create tests that verify error handling for:
    - Invalid file uploads
    - Network connection issues
    - Malformed data
    - User input validation
    Ensure error messages are user-friendly and helpful."
    """
    print("🧪 Testing error handling...")

    # Test 1: Missing required columns
    bad_data = pd.DataFrame({
        'Date': ['2024-08-01'],
        'WrongColumn': ['$50.00']
    })
    result = load_and_clean_transaction_data(bad_data)
    assert result is None, "Should return None for missing required columns"
    print("   ✅ Test 1 passed: Missing columns handled gracefully")

    # Test 2: Zero monthly contribution in savings calculator
    result = create_savings_calculator_tool(500, 0, 5000)
    assert "❌" in result, "Should return error for zero contribution"
    print("   ✅ Test 2 passed: Zero contribution handled correctly")

    # Test 3: Already reached savings goal
    result = create_savings_calculator_tool(5000, 200, 3000)
    assert "✅" in result, "Should return success message when goal already reached"
    print("   ✅ Test 3 passed: Already reached goal handled correctly")

    # Test 4: Empty DataFrame
    empty_data = pd.DataFrame(columns=['Date', 'Amount', 'Category', 'Description'])
    result = load_and_clean_transaction_data(empty_data)
    assert result is not None, "Should handle empty DataFrame without crashing"
    print("   ✅ Test 4 passed: Empty data handled gracefully")


# Run integration tests
try:
    test_full_workflow()
    test_error_handling()
    print("\n✅ Integration tests completed successfully!")
except AssertionError as e:
    print(f"❌ Test failed: {e}")
except Exception as e:
    print(f"⚠️ Integration test issue: {e}")
# Out:
# 🧪 Testing complete workflow integration...
# ✅ Data loaded successfully! 12 transactions found.
#    ✅ Step 1 passed: Data loading and cleaning works
# ...
# 📊 BUDGET BUDDY - SPENDING ANALYSIS REPORT
# ...
#
# 💰 Total Spending:   $658.90
# ↩️  Total Refunds:    $45.00
# 📉 Net Spending:     $613.90
#
# 📂 Spending by Category:
#    Rent                 $220.00  (33.4%)
#    Groceries            $212.70  (32.3%)
#    Entertainment        $130.00  (19.7%)
#    Utilities            $45.00  (6.8%)
#    Transport            $22.30  (3.4%)
#    Dining Out           $18.90  (2.9%)
#    Coffee               $10.00  (1.5%)
#
# 🏆 Top 3 Spending Categories:
#    1. Rent: $220.00
#    2. Groceries: $212.70
#    3. Entertainment: $130.00
#
# 🔺 Largest Single Purchase: Weekly Rent Payment ($220.00)
#
# ⚠️  High Spend Alert: Rent, Groceries exceeds 30% of total budget
#    ✅ Step 2 passed: Spending analysis pipeline works
# ...
# 💡 BUDGET BUDDY - FINANCIAL RECOMMENDATIONS
# ...
#
# 📋 SPENDING SUMMARY
# ...

# %% [markdown]
# ---
#
# # 📊 Project Completion Checklist
#
# ## Foundation Skills ✅
# - [ ] **Data Processing**: CSV loading and cleaning functions work reliably
# - [ ] **Analysis Functions**: Spending summaries calculate correctly
# - [ ] **Business Insights**: Recommendations are relevant and actionable
# - [ ] **Error Handling**: Graceful handling of data issues
# - [ ] **Testing**: Comprehensive test coverage for core functions
# - [ ] **Documentation**: Clear AI collaboration documentation in diary
#
# ## Advanced Integration ✅
# - [ ] **Chat Interface**: Finance advisor personality implemented
# - [ ] **RAG System**: Document retrieval for financial guidance
# - [ ] **Custom Tools**: At least one financial calculator/utility
# - [ ] **Gradio UI**: Professional, user-friendly interface
# - [ ] **Full Integration**: All components work together seamlessly
#
# ## Professional Standards ✅
# - [ ] **Code Quality**: Professional, commented, maintainable code
# - [ ] **Business Focus**: Clear connection to real finance problems
# - [ ] **User Experience**: Interface suitable for non-technical users
# - [ ] **AI Collaboration**: Extensive, well-documented AI usage
# - [ ] **Testing**: Robust validation of all features
#
# ## Project Documentation ✅
# - [ ] **Developer's Diary**: Complete AI collaboration documentation
# - [ ] **README**: Clear project description and usage instructions
# - [ ] **GitHub**: Regular commits showing development progress
# - [ ] **Reflection**: Thoughtful analysis of learning and challenges
#
# ---
#
# # 🎯 Final Thoughts: Your Finance Assistant Journey
#
# Congratulations on building your Smart Finance Assistant! This project represents a significant achievement in modern business programming:
#
# **Technical Skills Developed:**
# - AI-assisted development workflows
# - Professional data processing with pandas
# - Integration of multiple AI technologies
# - User interface design with Gradio
# - Comprehensive software testing
#
# **Business Skills Developed:**
# - Financial data analysis and insights
# - User-centered application design
# - Professional documentation practices
# - Iterative development methodology
# - Critical evaluation of AI suggestions
#
# **Professional Preparation:**
# - Experience with industry-standard AI collaboration
# - Portfolio-ready application development
# - Understanding of business problem-solving with technology
# - Documentation practices for workplace environments
#
# **Your Smart Finance Assistant demonstrates your ability to direct AI tools toward meaningful business solutions - exactly the skill set that modern BIS graduates need for career success!**
#
# ---
#
# *Remember to document all AI collaborations in your Developer's Diary and maintain regular GitHub commits throughout your development process.*
